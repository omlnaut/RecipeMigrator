// %%
import {ParsedRecipeProjection} from "./schemaOrgRecipe.ts"

const parsed: ParsedRecipeProjection = {
    title: "testi",
    description: "testi mac testface",
    ingredients: ["first", "second"],
    instructions: ["do first", "then do second"],
}

// %%
import {ToSchemaOrgRecipe} from "./schemaOrgRecipe.ts"
ToSchemaOrgRecipe(parsed)
// Out:
// {
//   "@context": "https://schema.org",
//   "@type": "Recipe",
//   name: "testi",
//   description: "testi mac testface",
//   recipeIngredient: [ "first", "second" ],
//   recipeInstructions: [
//     { "@type": "HowToStep", position: 1, text: "do first" },
//     { "@type": "HowToStep", position: 2, text: "then do second" }
//   ]
// }
