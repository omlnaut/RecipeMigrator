// %%
const MEALIE_API_BASE = "http://192.168.2.116:9090"

// %%
await fetch(MEALIE_API_BASE+"/docs")
// Out:
// Response {
//   body: ReadableStream { locked: false },
//   bodyUsed: false,
//   headers: Headers {
//     connection: "keep-alive",
//     "content-type": "text/html; charset=utf-8",
//     date: "Sun, 24 May 2026 08:13:27 GMT",
//     server: "nginx",
//     "transfer-encoding": "chunked",
//     vary: "Accept-Encoding",
//     "x-content-type-options": "nosniff",
//     "x-robots-tag": "none",
//     "x-xss-protection": "1; mode=block"
//   },
//   ok: true,
//   redirected: false,
//   status: 200,
//   statusText: "OK",
//   url: "http://192.168.2.116:9090/docs"
// }

// %%
Deno.env.get("MEALIE_USERNAME")
// Out:
// "omlnaut"

// %%
const body = new URLSearchParams({
  username: String(Deno.env.get("MEALIE_USERNAME") ?? ""),
  password: String(Deno.env.get("MEALIE_PASSWORD") ?? ""),
  remember_me: "false",
});

// %%
const response = await fetch(MEALIE_API_BASE + "/api/auth/token", {
  method: "POST",
  headers: {
    "Content-Type": "application/x-www-form-urlencoded",
    accept: "application/json",
  },
  body,
})

// %%
const raw_body = await response.json()

// %%
console.assert("access_token" in raw_body)

// %%
import {MealieClient} from "./mealie-client.ts"

// %%
const client = new MealieClient(
  {
    baseUrl: "http://192.168.2.116",
    port: 9090,
  },
  {
    username: String(Deno.env.get("MEALIE_USERNAME") ?? ""),
    password: String(Deno.env.get("MEALIE_PASSWORD") ?? ""),
  },
);

// %%
await client.Login()
// Out:
// Successfully fetched token eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiI0YmY4MWYyYi1kZGM0LTRjYzktOWJhMS00YmQ3NzNlOWFkMWYiLCJleHAiOjE4MTQxNzIwNzQsImlzcyI6Im1lYWxpZSJ9.kxFTP1REmjoBdB2A8x7Mwi2X4iJA_B_VoA6j_5SJ5Bs
